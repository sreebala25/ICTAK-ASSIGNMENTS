# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READING THE DATASET TO PYTHON ENVIRONMENT

# %%
data = pd.read_csv(r"F:\DS\ASSIGNMENTS\Assignment 3\iris.csv")

# %% [markdown]
# # Column Display

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Calculation of Mean of each column

# %%
data['SL'].mean()
# Out:
# 5.843333333333334

# %%
data['SW'].mean()
# Out:
# 3.0540000000000003

# %%
data['PL'].mean()
# Out:
# 3.758666666666666

# %%
data['PW'].mean()
# Out:
# 1.1986666666666668

# %% [markdown]
# # Checking for null values in the Dataset

# %%
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # Visualizations using Dataset

# %%
#BAR CHART
plt.bar(data['Classification'],data['SL'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#BOXPLOT
plt.boxplot(data['SL'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Pair Plot
sns.pairplot(data, hue='Classification')
plt.show()
